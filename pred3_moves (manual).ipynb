# %% [markdown]
# ## Initial graph

# %%
  digraph G {
  rankdir = TB;

  // defaults for L
  node [shape=record, color=red, style=filled]; 

L0 [label=" u1 | {  x1 | L0} |  λu1.x1"];
L1 [label=" u2 | {  u2 | L1} |  λu2.u2"];
L2 [label=" h | {  (h (g f1)) | L2} |  λh.(h (g f1))"];
L3 [label=" g | {  λh.(h (g f1)) | L3} |  λg.λh.(h (g f1))"];
L4 [label=" x1 | {  (((n λg.λh.(h (g f1))) λu1.x1) λu2.u2) | L4} |  λx1.(((n λg.λh.(h (g f1))) λu1.x1) λu2.u2)"];
L5 [label=" f1 | {  λx1.(((n λg.λh.(h (g f1))) λu1.x1) λu2.u2) | L5} |  λf1.λx1.(((n λg.λh.(h (g f1))) λu1.x1) λu2.u2)"];
L6 [label=" n | {  λf1.λx1.(((n λg.λh.(h (g f1))) λu1.x1) λu2.u2) | L6} |  λn.λf1.λx1.(((n λg.λh.(h (g f1))) λu1.x1) λu2.u2)"];
L7 [label=" x2 | {  (f2 (f2 (f2 x2))) | L7} |  λx2.(f2 (f2 (f2 x2)))"];
L8 [label=" f2 | {  λx2.(f2 (f2 (f2 x2))) | L8} |  λf2.λx2.(f2 (f2 (f2 x2)))"];
L9 [label=" PRED3 | {  (λn.λf1.λx1.(((n λg.λh.(h (g f1))) λu1.x1) λu2.u2) λf2.λx2.(f2 (f2 (f2 x2)))) | L9} |  λPRED3.(λn.λf1.λx1.(((n λg.λh.(h (g f1))) λu1.x1) λu2.u2) λf2.λx2.(f2 (f2 (f2 x2))))"];

  // defaults for A
  node [shape=record, color=green, style=filled]; 

A0 [label="
 g | { A0 |  (g f1)} |  f1"];
A1 [label="
 h | { A1 |  (h (g f1))} |  (g f1)"];
A2 [label="
 n | { A2 |  (n λg.λh.(h (g f1)))} |  λg.λh.(h (g f1))"];
A3 [label="
 (n λg.λh.(h (g f1))) | { A3 |  ((n λg.λh.(h (g f1))) λu1.x1)} |  λu1.x1"];
A4 [label="
 ((n λg.λh.(h (g f1))) λu1.x1) | { A4 |  (((n λg.λh.(h (g f1))) λu1.x1) λu2.u2)} |  λu2.u2"];
A5 [label="
 f2 | { A5 |  (f2 x2)} |  x2"];
A6 [label="
 f2 | { A6 |  (f2 (f2 x2))} |  (f2 x2)"];
A7 [label="
 f2 | { A7 |  (f2 (f2 (f2 x2)))} |  (f2 (f2 x2))"];
A8 [label="
 λn.λf1.λx1.(((n λg.λh.(h (g f1))) λu1.x1) λu2.u2) | { A8 |  (λn.λf1.λx1.(((n λg.λh.(h (g f1))) λu1.x1) λu2.u2) λf2.λx2.(f2 (f2 (f2 x2))))} |  λf2.λx2.(f2 (f2 (f2 x2)))"];

  // other
  T [ shape=point, color=black, style=filled ]
  FRIN [ style=filled, color=blue ]
  FROUT [ style=filled, color=blue ]

L0:lo -> FROUT
L4:lo -> L0:mi
L0:ro -> A3:ri
L1:lo -> L1:mi
L1:ro -> A4:ri
L3:lo -> A0:li
A0:mo -> A1:ri
L5:lo -> A0:ri
L2:lo -> A1:li
A1:mo -> L2:mi
L2:ro -> L3:mi
L3:ro -> A2:ri
A2:mo -> A3:li
A3:mo -> A4:li
A4:mo -> L4:mi
L4:ro -> L5:mi
L8:lo -> A5:li
L8:lo -> A6:li
L8:lo -> A7:li
A5:mo -> A6:ri
L7:lo -> A5:ri
A6:mo -> A7:ri
A7:mo -> L7:mi
L7:ro -> L8:mi
L9:lo -> FROUT
L9:ro -> FROUT

L6:lo -> A2:li
L5:ro -> L6:mi
L8:ro -> A8:ri
A8:mo -> L9:mi

L6:ro -> A8:li
}

# %% [markdown]
# ## Move 1: beta

# %%
  digraph G {
  rankdir = TB;

  // defaults for L
  node [shape=record, color=red, style=filled]; 

L0 [label=" u1 | {  x1 | L0} |  λu1.x1"];
L1 [label=" u2 | {  u2 | L1} |  λu2.u2"];
L2 [label=" h | {  (h (g f1)) | L2} |  λh.(h (g f1))"];
L3 [label=" g | {  λh.(h (g f1)) | L3} |  λg.λh.(h (g f1))"];
L4 [label=" x1 | {  (((n λg.λh.(h (g f1))) λu1.x1) λu2.u2) | L4} |  λx1.(((n λg.λh.(h (g f1))) λu1.x1) λu2.u2)"];
L5 [label=" f1 | {  λx1.(((n λg.λh.(h (g f1))) λu1.x1) λu2.u2) | L5} |  λf1.λx1.(((n λg.λh.(h (g f1))) λu1.x1) λu2.u2)"];
L7 [label=" x2 | {  (f2 (f2 (f2 x2))) | L7} |  λx2.(f2 (f2 (f2 x2)))"];
L8 [label=" f2 | {  λx2.(f2 (f2 (f2 x2))) | L8} |  λf2.λx2.(f2 (f2 (f2 x2)))"];
L9 [label=" PRED3 | {  (λn.λf1.λx1.(((n λg.λh.(h (g f1))) λu1.x1) λu2.u2) λf2.λx2.(f2 (f2 (f2 x2)))) | L9} |  λPRED3.(λn.λf1.λx1.(((n λg.λh.(h (g f1))) λu1.x1) λu2.u2) λf2.λx2.(f2 (f2 (f2 x2))))"];

  // defaults for A
  node [shape=record, color=green, style=filled]; 

A0 [label="
 g | { A0 |  (g f1)} |  f1"];
A1 [label="
 h | { A1 |  (h (g f1))} |  (g f1)"];
A2 [label="
 n | { A2 |  (n λg.λh.(h (g f1)))} |  λg.λh.(h (g f1))"];
A3 [label="
 (n λg.λh.(h (g f1))) | { A3 |  ((n λg.λh.(h (g f1))) λu1.x1)} |  λu1.x1"];
A4 [label="
 ((n λg.λh.(h (g f1))) λu1.x1) | { A4 |  (((n λg.λh.(h (g f1))) λu1.x1) λu2.u2)} |  λu2.u2"];
A5 [label="
 f2 | { A5 |  (f2 x2)} |  x2"];
A6 [label="
 f2 | { A6 |  (f2 (f2 x2))} |  (f2 x2)"];
A7 [label="
 f2 | { A7 |  (f2 (f2 (f2 x2)))} |  (f2 (f2 x2))"];

  // other
  T [ shape=point, color=black, style=filled ]
  FRIN [ style=filled, color=blue ]
  FROUT [ style=filled, color=blue ]

// beta moved nodes
  node [shape=record, color=purple, style=filled]; 
L6 [label=" n | {  λf1.λx1.(((n λg.λh.(h (g f1))) λu1.x1) λu2.u2) | L6} |  λn.λf1.λx1.(((n λg.λh.(h (g f1))) λu1.x1) λu2.u2)"];
A8 [label="
 λn.λf1.λx1.(((n λg.λh.(h (g f1))) λu1.x1) λu2.u2) | { A8 |  (λn.λf1.λx1.(((n λg.λh.(h (g f1))) λu1.x1) λu2.u2) λf2.λx2.(f2 (f2 (f2 x2))))} |  λf2.λx2.(f2 (f2 (f2 x2)))"];

// edges
L0:lo -> FROUT
L4:lo -> L0:mi
L0:ro -> A3:ri
L1:lo -> L1:mi
L1:ro -> A4:ri
L3:lo -> A0:li
A0:mo -> A1:ri
L5:lo -> A0:ri
L2:lo -> A1:li
A1:mo -> L2:mi
L2:ro -> L3:mi
L3:ro -> A2:ri
A2:mo -> A3:li
A3:mo -> A4:li
A4:mo -> L4:mi
L4:ro -> L5:mi
L8:lo -> A5:li
L8:lo -> A6:li
L8:lo -> A7:li
A5:mo -> A6:ri
L7:lo -> A5:ri
A6:mo -> A7:ri
A7:mo -> L7:mi
L7:ro -> L8:mi
L9:lo -> FROUT
L9:ro -> FROUT

# beta move 1: L6, A8
# red: deleted edges
# green: new edges
L6:lo -> A2:li [color=red, style=dotted, label=1]
L5:ro -> L6:mi [color=red, style=dotted, label=1]
L8:ro -> A8:ri [color=red, style=dotted, label=1]
A8:mo -> L9:mi [color=red, style=dotted, label=1]
L8:lo -> A2:li [color=green, style=solid, label=1]
L5:ro -> L9:mi [color=green, style=solid, label=1]

# island
L6:ro -> A8:li
}

# %% [markdown]
# ## Move 2: beta

# %%
  digraph G {
  rankdir = TB;

  // defaults for L
  node [shape=record, color=red, style=filled]; 

L0 [label=" u1 | {  x1 | L0} |  λu1.x1"];
L1 [label=" u2 | {  u2 | L1} |  λu2.u2"];
L2 [label=" h | {  (h (g f1)) | L2} |  λh.(h (g f1))"];
L3 [label=" g | {  λh.(h (g f1)) | L3} |  λg.λh.(h (g f1))"];
L4 [label=" x1 | {  (((n λg.λh.(h (g f1))) λu1.x1) λu2.u2) | L4} |  λx1.(((n λg.λh.(h (g f1))) λu1.x1) λu2.u2)"];
L5 [label=" f1 | {  λx1.(((n λg.λh.(h (g f1))) λu1.x1) λu2.u2) | L5} |  λf1.λx1.(((n λg.λh.(h (g f1))) λu1.x1) λu2.u2)"];
L6 [label=" n | {  λf1.λx1.(((n λg.λh.(h (g f1))) λu1.x1) λu2.u2) | L6} |  λn.λf1.λx1.(((n λg.λh.(h (g f1))) λu1.x1) λu2.u2)"];
L7 [label=" x2 | {  (f2 (f2 (f2 x2))) | L7} |  λx2.(f2 (f2 (f2 x2)))"];
L9 [label=" PRED3 | {  (λn.λf1.λx1.(((n λg.λh.(h (g f1))) λu1.x1) λu2.u2) λf2.λx2.(f2 (f2 (f2 x2)))) | L9} |  λPRED3.(λn.λf1.λx1.(((n λg.λh.(h (g f1))) λu1.x1) λu2.u2) λf2.λx2.(f2 (f2 (f2 x2))))"];

  // defaults for A
  node [shape=record, color=green, style=filled]; 

A0 [label="
 g | { A0 |  (g f1)} |  f1"];
A1 [label="
 h | { A1 |  (h (g f1))} |  (g f1)"];
A3 [label="
 (n λg.λh.(h (g f1))) | { A3 |  ((n λg.λh.(h (g f1))) λu1.x1)} |  λu1.x1"];
A4 [label="
 ((n λg.λh.(h (g f1))) λu1.x1) | { A4 |  (((n λg.λh.(h (g f1))) λu1.x1) λu2.u2)} |  λu2.u2"];
A5 [label="
 f2 | { A5 |  (f2 x2)} |  x2"];
A6 [label="
 f2 | { A6 |  (f2 (f2 x2))} |  (f2 x2)"];
A7 [label="
 f2 | { A7 |  (f2 (f2 (f2 x2)))} |  (f2 (f2 x2))"];
A8 [label="
 λn.λf1.λx1.(((n λg.λh.(h (g f1))) λu1.x1) λu2.u2) | { A8 |  (λn.λf1.λx1.(((n λg.λh.(h (g f1))) λu1.x1) λu2.u2) λf2.λx2.(f2 (f2 (f2 x2))))} |  λf2.λx2.(f2 (f2 (f2 x2)))"];

  // other
  T [ shape=point, color=black, style=filled ]
  FRIN [ style=filled, color=blue ]
  FROUT [ style=filled, color=blue ]

// beta move 2: L8, A2
node [shape=record, color=purple, style=filled]; 
L8 [label=" f2 | {  λx2.(f2 (f2 (f2 x2))) | L8} |  λf2.λx2.(f2 (f2 (f2 x2)))"];
A2 [label="
 n | { A2 |  (n λg.λh.(h (g f1)))} |  λg.λh.(h (g f1))"];

// edges
L0:lo -> FROUT
L4:lo -> L0:mi
L0:ro -> A3:ri
L1:lo -> L1:mi
L1:ro -> A4:ri
L3:lo -> A0:li
A0:mo -> A1:ri
L5:lo -> A0:ri
L2:lo -> A1:li
A1:mo -> L2:mi
L2:ro -> L3:mi
A3:mo -> A4:li
A4:mo -> L4:mi
L4:ro -> L5:mi
L6:ro -> A8:li
A5:mo -> A6:ri
L7:lo -> A5:ri
A6:mo -> A7:ri
A7:mo -> L7:mi
L9:lo -> FROUT
L9:ro -> FROUT

# beta move 1
L5:ro -> L9:mi [label=1]

# beta move 2: L8, A2
L3:ro -> A2:ri [color=red, style=dotted, label=2]
A2:mo -> A3:li [color=red, style=dotted, label=2]
L8:lo -> A5:li [color=red, style=dotted, label=2]
L8:lo -> A6:li [color=red, style=dotted, label=2]
L8:lo -> A7:li [color=red, style=dotted, label=2]
L7:ro -> L8:mi [color=red, style=dotted, label=2]
L3:ro -> A5:li [color=green, style=solid, label=2]
L3:ro -> A6:li [color=green, style=solid, label=2]
L3:ro -> A7:li [color=green, style=solid, label=2]
L7:ro -> A3:li [color=green, style=solid, label=2]

# island
L8:lo -> A2:li [label=1]

}
